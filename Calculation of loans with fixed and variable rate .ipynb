# %%
CALCULATION OF LOANS WITH FIXED AND VARIABLE RATE

# %%
#Importar Biblioteca Matemáticas Python

import math


# Definir Variables con parámetros globales 
    
def introducirNumeros ():
    global P,n,i
    
    P=float(input("Introduzca el Valor Presente:"))
    n=int(input("Introduzca el Número de Períodos:"))
    i=int(input("Introduzca la Tasa de Interés:"))
    
def introducirNumeros2 ():
    global F,n,i    
    
    
    F= float(input("Introduzca el Valor Futuro:"))
    n=int(input("Introduzca el Número de Períodos:"))
    i=int(input("Introduzca la Tasa de Interés:"))
    
def introducirNumeros3 ():
    global F,P,i    
    
    F= float(input("Introduzca el Valor Futuro:"))
    P=float(input("Introduzca el Valor Presente:"))
    i=int(input("Introduzca la Tasa de Interés:"))
    
def introducirNumeros4 ():
    global F,P,n   
    
    F= float(input("Introduzca el Valor Futuro:"))
    P=float(input("Introduzca el Valor Presente:"))
    n=int(input("Introduzca el Número de Períodos:"))
    
    
#Variables para el cálculo del Préstamo con Interés Fijo"

def ValorFuturo(P,n,i):
    print("El Valor Futuro es igual a :",round(P*(1+((i/100)*n)),2))

def ValorPresente(F,n,i):
    print("El Valor Presente es igual a :", round(F/(1+((i/100)*n)),2))
    
def NumeroPeriodos(F,P,i):
          print("El total de periodos es:", round((((F/P)-1)/(i/100)),2))
    
def PorcientoTasaInteres(F,P,n):
          if n==0:
            print("No se puede dividir entre cero")
          else:
            print("El Valor de la Tasa de Interes es el siguiente:", round((((F/P)-1)/n),2))
            
def Interes(P,i,n):
    print( "El Valor del Interés Ganado es el siguiente:",round(P*(i/100)*n,2))

    
#Variables para el cálculo del Préstamo con Interés Variable" 
    
def ValorFuturo2(P,n,i):
    
    print("El Valor Futuro es igual a :", round(P*((1+(i/100))**n),2))
    
def ValorPresente2(F,n,i):
    print("El Valor Presente es igual a :",round(F*((1+(i/100))**-n),2))
    
def NumeroPeriodos2(F,P,i):
    print("El total de periodos es:",round(math.log10(F/P)/math.log10(1+(i/100)),2))

def PorcientoTasaInteres2(F,P,n):
    print("El Valor de la Tasa de Interes es el siguiente:", round(((F/P)-1)**(1/n),2))
    
def Interes2 (P,i,n):
    print("El Valor del Interés Ganado es el siguiente:", round(P*((1+(i/100))**n -1),2))
    
           
    
    
print("""
Indique la operación a realizar:

(1) Formulas de Interés Simple
(2) Formulas de Interés Compuesto
(3) Salir del Programa
""")
    
OpcionCalculo= int(input("Escoja la opción de Cálculo del préstamo: "))

                    
if OpcionCalculo==1:
    print ("Escogió usted hacer el cálculo de Interés Simple.")
    print("""
    Indique la incógnita a Buscar:        
    4)  VALOR FUTURO
    5)  VALOR PRESENTE
    6)  TOTAL DE PERIODOS DE CAPITALIZACION
    7)  TASA DE INTERES
    8)  INTERES GANADO
    """)
                    
    OpcionIncognita= int(input("Escoja la incógnita a Buscar: "))

                
                     
    if (OpcionIncognita == 4):
            introducirNumeros ()
            ValorFuturo(P,n,i)
            
                     
    elif (OpcionIncognita == 5):
        introducirNumeros2()
        ValorPresente(F,n,i)
        
                                                            
    elif (OpcionIncognita == 6):
        introducirNumeros3()
        NumeroPeriodos(F,P,i)
        
    
    elif (OpcionIncognita == 7):
        introducirNumeros4()
        PorcientoTasaInteres(F,P,n)
        
                       
    elif (OpcionIncognita == 8):
        introducirNumeros()
        Interes(P,i,n)
    else:
        print("Continuar")
               
if OpcionCalculo ==2:
    print ("Escogió usted hacer el cálculo de Interés Compuesto.")
    print("""
    Indique la incógnita a Buscar:
    9)  VALOR FUTURO
   10)  VALOR PRESENTE
   11)  TOTAL DE PERIODOS DE CAPITALIZACION
   12)  TASA DE INTERES
   13)  INTERES GANADO
    """)
    
    OpcionIncognita= int(input("Escoja la incógnita a Buscar: "))
        
    if (OpcionIncognita == 9):
        introducirNumeros()
        ValorFuturo2(P,n,i)
                     
        
    elif (OpcionIncognita == 10):
        introducirNumeros2()
        ValorPresente2(F,n,i)
                                                              
    elif (OpcionIncognita == 11):
        introducirNumeros3()
        NumeroPeriodos2(F,P,i)
                                                            
    elif (OpcionIncognita == 12):
        introducirNumeros4()
        PorcientoTasaInteres2(F,P,n)
                       
    elif (OpcionIncognita == 13):
        introducirNumeros()
        Interes2(P,i,n)

    else:
        print("Esta opción no es permitida")

   
    
if OpcionCalculo ==3:
    print("Usted salió el programa....Adios")
        
else:
        print("Gracias Por Su Consulta")
# Out:
# Indique la operación a realizar:
#
# (1) Formulas de Interés Simple
# (2) Formulas de Interés Compuesto
# (3) Salir del Programa
#
# Escoja la opción de Cálculo del préstamo: 2
# Escogió usted hacer el cálculo de Interés Compuesto.
#
#     Indique la incógnita a Buscar:
#     9)  VALOR FUTURO
#    10)  VALOR PRESENTE
#    11)  TOTAL DE PERIODOS DE CAPITALIZACION
#    12)  TASA DE INTERES
#    13)  INTERES GANADO
#
# Escoja la incógnita a Buscar: 12
# Introduzca el Valor Futuro:1000
# Introduzca el Valor Presente:120
# Introduzca el Número de Períodos:10
# El Valor de la Tasa de Interes es el siguiente: 1.22
# Gracias Por Su Consulta
